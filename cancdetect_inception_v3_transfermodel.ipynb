# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,GlobalAveragePooling2D,Flatten
from sklearn.datasets import load_files
from keras.utils import np_utils
import numpy as np
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
bottleneck_train=np.load('bottleneck_train_inception_v3_cancdetect')
bottleneck_valid=np.load('bottleneck_valid_inception_v3_cancdetect')
bottleneck_test=np.load('bottleneck_test_inception_v3_cancdetect')

# %%
bottleneck_train.shape
# Out:
# (2000, 6, 6, 2048)

# %%
trainfiles=load_files('data/train/')
train_filenames=trainfiles['filenames']
train_targets=np_utils.to_categorical(trainfiles['target'])

validfiles=load_files('data/valid/')
valid_filenames=validfiles['filenames']
valid_targets=np_utils.to_categorical(validfiles['target'])

testfiles=load_files('data/test/')
test_filenames=testfiles['filenames']
test_targets=np_utils.to_categorical(testfiles['target'])

# %%
model=Sequential()
model.add(GlobalAveragePooling2D(input_shape=bottleneck_train.shape[1:]))
# model.add(Dense(units=1000,activation='relu'))
model.add(Dense(units=len(trainfiles['target_names']),activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 6147
# =================================================================
# Total params: 6,147.0
# Trainable params: 6,147.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='rmsprop')

# %%
checkpointer=ModelCheckpoint(filepath='cancdetect_transfer_inception_v3.weights.best.hdf5',verbose=1,save_best_only=True)

model.fit(bottleneck_train,train_targets,batch_size=10,epochs=100,shuffle=True,verbose=1,callbacks=[checkpointer],
             validation_data=[bottleneck_valid,valid_targets])
# Out:
# Train on 2000 samples, validate on 146 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 0.91599, saving model to cancdetect_transfer_inception_v3.weights.best.hdf5
# 2000/2000 [==============================] - 20s - loss: 0.8452 - acc: 0.6625 - val_loss: 0.9160 - val_acc: 0.5822
# Epoch 2/100
# Epoch 00001: val_loss improved from 0.91599 to 0.86339, saving model to cancdetect_transfer_inception_v3.weights.best.hdf5
# 2000/2000 [==============================] - 1s - loss: 0.7013 - acc: 0.7245 - val_loss: 0.8634 - val_acc: 0.6301
# Epoch 3/100
# Epoch 00002: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.6385 - acc: 0.7285 - val_loss: 0.9305 - val_acc: 0.6027
# Epoch 4/100
# Epoch 00003: val_loss improved from 0.86339 to 0.77591, saving model to cancdetect_transfer_inception_v3.weights.best.hdf5
# 2000/2000 [==============================] - 1s - loss: 0.6038 - acc: 0.7450 - val_loss: 0.7759 - val_acc: 0.6438
# Epoch 5/100
# Epoch 00004: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.5798 - acc: 0.7560 - val_loss: 0.8834 - val_acc: 0.6301
# Epoch 6/100
# Epoch 00005: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.5499 - acc: 0.7820 - val_loss: 0.9648 - val_acc: 0.5959
# Epoch 7/100
# Epoch 00006: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.5220 - acc: 0.7810 - val_loss: 0.7795 - val_acc: 0.6849
# Epoch 8/100
# Epoch 00007: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.5065 - acc: 0.7845 - val_loss: 0.9802 - val_acc: 0.6027
# Epoch 9/100
# Epoch 00008: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.4920 - acc: 0.7990 - val_loss: 0.8576 - val_acc: 0.5890
# Epoch 10/100
# Epoch 00009: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.4731 - acc: 0.8040 - val_loss: 0.7896 - val_acc: 0.6849
# Epoch 11/100
# Epoch 00010: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.4562 - acc: 0.8060 - val_loss: 0.8715 - val_acc: 0.6096
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.4568 - acc: 0.8065 - val_loss: 0.8335 - val_acc: 0.7123
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.4268 - acc: 0.8325 - val_loss: 0.8995 - val_acc: 0.6781
# Epoch 14/100
# Epoch 00013: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.4250 - acc: 0.8295 - val_loss: 0.7920 - val_acc: 0.6781
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.4046 - acc: 0.8310 - val_loss: 0.8219 - val_acc: 0.6301
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.3903 - acc: 0.8400 - val_loss: 0.9933 - val_acc: 0.6164
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.3884 - acc: 0.8390 - val_loss: 1.0684 - val_acc: 0.6507
# Epoch 18/100
# Epoch 00017: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.3823 - acc: 0.8465 - val_loss: 1.3027 - val_acc: 0.5959
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.3689 - acc: 0.8540 - val_loss: 0.8085 - val_acc: 0.6986
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.3594 - acc: 0.8585 - val_loss: 1.1590 - val_acc: 0.6027
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.3408 - acc: 0.8650 - val_loss: 0.9536 - val_acc: 0.6918
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.3415 - acc: 0.8635 - val_loss: 0.8321 - val_acc: 0.6781
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.3362 - acc: 0.8680 - val_loss: 1.1412 - val_acc: 0.6507
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 2000/2000 [==============================] - 1s - loss: 0.